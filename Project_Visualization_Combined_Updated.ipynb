# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, RocCurveDisplay, ConfusionMatrixDisplay, classification_report

# %%
""" 
This function prints out a confusion matrix specifically for this task. The labels are defined inside the function for that reason.
It will print the confusion matrix values as percentages by default and raw counts if the data is specified otherwise.
"""
def print_ConfusionMatrix(cm:confusion_matrix, title:str, normalized:bool):
    labels = ["Looking for job", "Not looking for job"]

    plt.figure(figsize=(6, 5))
    if(normalized == True):
        fmt = ".2%"
    else:
        fmt = "d"
    sns.heatmap(cm, annot=True, fmt = fmt, cmap='coolwarm',
                xticklabels=labels, yticklabels=labels)
    plt.title(title)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %%
train_data = pd.read_csv("aug_train.csv", delimiter = ",")
test_data = pd.read_csv("aug_test.csv", delimiter = ",")

# %%
train_data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target
# 0                  36     1.0
# 1                  47     0.0
# 2                  83     0.0
# 3                  52     1.0
# 4                   8     0.0
# ...               ...     ...
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0
#
# [19158 rows x 14 columns]

# %%
test_data.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# 2              NaN         <1          NaN      Pvt Ltd        never
# 3             STEM         11        10/49      Pvt Ltd            1
# 4             STEM        >20       10000+      Pvt Ltd           >4
#
#    training_hours
# 0              21
# 1              98
# 2              15
# 3              39
# 4              72

# %% [markdown]
# We plan to create a classification model that can  accurately predict if people are looking for a job change or not. The predictors we plan to look at are: company type, company size, training hours, last new job, education level, experience, and relevant experience.
#
# Important things to note:
# There are quite a lot of missing values: 32% of the company type responses are missing values, which could be for a variety of reasons, maybe some people do not know the type of company they work for, have NDA's. That's a good chunck of the data to just ignore, so we plan to keep track of them using: dummy_na is 'True' for get dummies
#
# 29% missing values for company size, 2% missing values for last new job, <1% for experience, and 2% for education level.

# %% [markdown]
# First, we will be visualizing the data of our chosen predictors before splitting the data.

# %%
#Define style to use for visualizations
plt.style.use("petroff10")

#Pie chart to understand the distribution of people looking for a job (where target = 1), and people that will be staying (where target = 0)
labels = ["Looking for job", "Not looking for job"]
Job_Change = train_data["target"].sum()
No_Job_Change = (train_data["target"] == False).sum()
counts = [Job_Change, No_Job_Change]

plt.pie(counts, labels=labels, autopct='%.1f%%', startangle=90)
plt.title("New Job Interest Distribution")
plt.axis('equal')  # Equal aspect ratio makes the pie circular
plt.figure(dpi = 300)
plt.show()

# %%
#Plotting the predictor (company type to our target)
sns.countplot(x='company_type', hue='target', stat= "percent" ,data=train_data)
plt.title("Company type vs Job Change")
plt.legend(title = "Looking for a Job?", labels = ["Not looking","Looking"] )
plt.xticks(rotation=34)
plt.figure(dpi = 300)
plt.show()

# %% [markdown]
# One thing we do notice is that the higher the percentage of people, from a particular group willing to stay, the higher the people looking for a job change within that same group which makes sense in hindsight. In this case, the people workng in the private limited company, Pvt Ltd, are more willing to stay with the company after training, but they also have the higher percentage, when comparing amongst others, of people looking to branch out. The other company types have a smaller population, so their contributions are understandably lower.

# %%
#Plotting the predictor (education level to our target)
sns.countplot(x='education_level', hue='target', stat="percent", data=train_data)
plt.title("Education Level vs Job Change")
plt.legend(title = "Looking for a Job?", labels = ["Not looking","Looking"] )
plt.xticks(rotation=34)
plt.figure(dpi = 300)

# %% [markdown]
# Similarly, when looking at results from their education level, graduates make up more of the population in this case and as a result, have a higher percentage of people both willing to stay and willing to leave, compared to the other levels like masters and Phd students. It was not specified what exactly graduates mean as they have both masters and Phd students as differnt options in this category, but we assume that 'graduates' refer to people that have completed their undergraduate degree.

# %%
#Plotting the predictor (training hours to our target)
sns.histplot(data=train_data, x='training_hours', hue='target', stat='density', common_norm=False)
plt.title("Training hours vs Job Change")
# Out:
# Text(0.5, 1.0, 'Training hours vs Job Change')

# %% [markdown]
# Training hours are numerical value, so we chose to visualize them using historgramsa density plot. Training hours refer to how long the participants have spent training with the company. There seems to be a lot of overlap between the poeple who choose to stay and the people that choose to leave the company in search of a new job. Additionally, the data is skewed where more people have less than 100 hours in training.

# %%
#Plotting the predictor (last new job to our target)
sns.countplot(x='last_new_job', hue='target', data=train_data)
plt.legend(title = "Looking for a Job?", labels = ["Not looking","Looking"] )
plt.title("Last new job vs Job Change")
plt.xticks(rotation=0)
plt.figure(dpi = 300)

# %% [markdown]
# The variable 'last new job' works similarly to the predictor company type, because the more the population within a particularly category, the higher the percentage of people both looking to stay and leave.

# %%
#Plotting the predictor (company size to our target)
sns.countplot(x='company_size', hue='target', data=train_data)
plt.title("Company size vs Job Change")
plt.legend(labels = ["Not looking","Looking"] )
plt.xticks(rotation=34)
plt.figure(dpi = 300)

# %% [markdown]
# The variable company size works similarly to the predictor company type, because the more the population within a particularly category, the higher the percentage of people both looking to stay and leave.

# %%
#Plotting the preidctor (relevant experience to target)

#This should be two different pie charts showing the distribution of relevant experience for people looking for jobs vs those not 
labels = ["Has experience", "No experience"]
dummies_rel_exp = pd.get_dummies(train_data["relevent_experience"])
rel_exp = dummies_rel_exp["Has relevent experience"].sum()
no_rel_exp = dummies_rel_exp["No relevent experience"].sum()
counts = [rel_exp, no_rel_exp]

plt.pie(counts, labels=labels, autopct='%.1f%%', startangle=90)
plt.title("Relevant experience vs Job Change")
plt.legend(labels = ["Has experience", "No experience"])
plt.axis('equal')
plt.figure(dpi = 300)
plt.show()

# %% [markdown]
# This pie chart shows the distribution of applicants/people that have relevant experience compared to the people that do not have relevant experience. It was not specified, but we assumed relevant experience to refer to people with direct experience in the field of data science prior to being involved in this program

# %%
#Plotting the predictor (experience to target)
sns.countplot(x='experience', hue='target', data=train_data)
plt.title("Experience vs Job Change")
plt.legend(labels = ["Not looking","Looking"] )
plt.xticks(rotation=65)
plt.figure(dpi = 300)

# %% [markdown]
# We notice a similar trend, the more the population of people in a category, the higher the percentage of people willing to stay and willing to leave. Additionally, it was not really clear the distinction between the variables 'relevant experience' and 'experience', but 'experience' refers to the total experience of a candidate in years, which we assumed to be total experience they have in their present field. We assumed this because there were instances where a candidate had 'no experience' in the 'relevant experience' category, but they had experience in the 'experience' variable.

# %%
#Converting categorical varaiables to dummy 
train_data.drop("city",axis=1,inplace=True)
train_dummies = pd.get_dummies(train_data, dummy_na= True)

labels = train_dummies["target"]
train_dummies.drop(["target","relevent_experience_nan","enrollee_id"], axis = 1,inplace = True)
x_train, x_test, y_train, y_test = train_test_split(train_dummies, labels, test_size = 0.2, random_state = 21)

# %%
train_dummies
# Out:
#        city_development_index  training_hours  gender_Female  gender_Male  \
# 0                       0.920              36          False         True
# 1                       0.776              47          False         True
# 2                       0.624              83          False        False
# 3                       0.789              52          False        False
# 4                       0.767               8          False         True
# ...                       ...             ...            ...          ...
# 19153                   0.878              42          False         True
# 19154                   0.920              52          False         True
# 19155                   0.920              44          False         True
# 19156                   0.802              97          False         True
# 19157                   0.855             127          False        False
#
#        gender_Other  gender_nan  relevent_experience_Has relevent experience  \
# 0             False       False                                         True
# 1             False       False                                        False
# 2             False        True                                        False
# 3             False        True                                        False
# 4             False       False                                         True
# ...             ...         ...                                          ...
# 19153         False       False                                        False
# 19154         False       False                                         True
# 19155         False       False                                         True
# 19156         False       False                                         True
# 19157         False        True                                        False
#
#        relevent_experience_No relevent experience  \
# 0                                           False
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                           False
# ...                                           ...
# 19153                                        True
# 19154                                       False
# 19155                                       False
# 19156                                       False
# 19157                                        True
#
#        enrolled_university_Full time course  \
# 0                                     False
# 1                                     False
# 2                                      True
# 3                                     False
# 4                                     False
# ...                                     ...
# 19153                                 False
# 19154                                 False
# 19155                                 False
# 19156                                 False
# 19157                                 False
#
#        enrolled_university_Part time course  ...  company_type_Public Sector  \
# 0                                     False  ...                       False
# 1                                     False  ...                       False
# 2                                     False  ...                       False
# 3                                     False  ...                       False
# 4                                     False  ...                       False
# ...                                     ...  ...                         ...
# 19153                                 False  ...                       False
# 19154                                 False  ...                       False
# 19155                                 False  ...                       False
# 19156                                 False  ...                       False
# 19157                                 False  ...                       False
#
#        company_type_Pvt Ltd  company_type_nan  last_new_job_1  last_new_job_2  \
# 0                     False              True            True           False
# 1                      True             False           False           False
# 2                     False              True           False           False
# 3                      True             False           False           False
# 4                     False             False           False           False
# ...                     ...               ...             ...             ...
# 19153                 False              True            True           False
# 19154                 False              True           False           False
# 19155                  True             False           False           False
# 19156                  True             False           False            True
# 19157                 False              True            True           False
#
#        last_new_job_3  last_new_job_4  last_new_job_>4  last_new_job_never  \
# 0               False           False            False               False
# 1               False           False             True               False
# 2               False           False            False                True
# 3               False           False            False                True
# 4               False            True            False               False
# ...               ...             ...              ...                 ...
# 19153           False           False            False               False
# 19154           False            True            False               False
# 19155           False            True            False               False
# 19156           False           False            False               False
# 19157           False           False            False               False
#
#        last_new_job_nan
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 19153             False
# 19154             False
# 19155             False
# 19156             False
# 19157             False
#
# [19158 rows x 71 columns]

# %%
train_dummies.head()
# Out:
#    city_development_index  training_hours  gender_Female  gender_Male  \
# 0                   0.920              36          False         True
# 1                   0.776              47          False         True
# 2                   0.624              83          False        False
# 3                   0.789              52          False        False
# 4                   0.767               8          False         True
#
#    gender_Other  gender_nan  relevent_experience_Has relevent experience  \
# 0         False       False                                         True
# 1         False       False                                        False
# 2         False        True                                        False
# 3         False        True                                        False
# 4         False       False                                         True
#
#    relevent_experience_No relevent experience  \
# 0                                       False
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                       False
#
#    enrolled_university_Full time course  enrolled_university_Part time course  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                  True                                 False
# 3                                 False                                 False
# 4                                 False                                 False
#
#    ...  company_type_Public Sector  company_type_Pvt Ltd  company_type_nan  \
# 0  ...                       False                 False              True
# 1  ...                       False                  True             False
# 2  ...                       False                 False              True
# 3  ...                       False                  True             False
# 4  ...                       False                 False             False
#
#    last_new_job_1  last_new_job_2  last_new_job_3  last_new_job_4  \
# 0            True           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False
# 4           False           False           False            True
#
#    last_new_job_>4  last_new_job_never  last_new_job_nan
# 0            False               False             False
# 1             True               False             False
# 2            False                True             False
# 3            False                True             False
# 4            False               False             False
#
# [5 rows x 71 columns]

# %%
#normalize training, validation, test data
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
#Applying the random forest model to our training set
rf_model = RandomForestClassifier(bootstrap=True, class_weight="balanced", n_estimators=50,
                                  min_samples_split=15)
rf_model.fit(x_train, y_train)
y_pred = rf_model.predict(x_train)

# %%
#Determining the accuracy of the model: How accurate is it in predicting the people that would leave?
hr_probs = rf_model.predict_proba(x_train)
hr_probs = hr_probs[:, 1]

threshold = 0.50
preds = (hr_probs >= threshold).astype(y_train.dtype)

hr_acc = np.mean(preds == y_train)
base_rate = np.mean(y_train)
rel_acc = np.abs((1 - base_rate) - hr_acc) * 100

print(f"Model Accuracy: {hr_acc:.5f}")
print(f"Model Relative Accuracy: {rel_acc:.2f}%")
# Out:
# Model Accuracy: 0.85593
# Model Relative Accuracy: 10.54%

# %%
#Plotting the confusion matrix for the training data
train_results = (x_train.sum(axis=1) >= 6).astype(y_train.dtype)
train_cm = confusion_matrix(y_pred, y_train, normalize = "true")

print_ConfusionMatrix(train_cm, "Normalized Confusion Matrix for Training Set", normalized = True)

# %% [markdown]
# These results help us determine and understand the accuracy of our random forest model. The model has an accuracy of 0.85 indicating that it is doing a good job predicting the number of people that plan to leave the company for a new job after the training session is over. There could be a couple of reasons for this, but one of the major ones would be because of the breakdown of people planning to leave and stay after the training period.
#
# The number or people planning to leave the company is significantly lower than the number of people that plan to stay, with a percent of ~ 30%. Because the number of people planning to leave is very low, our model is guaranteed to do a good job predicting this percentage, but an anticipated problem would be on the false positives when the model is run on the test data. We are more prone to having more false positives due to the high accuracy of the model but small number of people that plan to leave.
#
# The confusion matrix and accuracy score suggest that our Random Forest model is performing fairly well on the training set, with an accuracy of 85.87%. The matrix shows that:
#
# 94.03% of people who are actually looking for a job were correctly predicted, and that
#
# 67.54% of people who are not looking for a job were also correctly predicted.
#
# The rates of false positives (when we predict that they stay but thet leave) and false negatives (when we predict that they leave, but they stay) are both less than 40%, with false positives being siginficantly higher than false negatives.
#
# There are a couple reasons why our model is doing such a good job predicting why people leave after the training program and one of the major reasons for that is because of the class imbalance, which was one of the things to be noted about the dataset. The people willing to stay after training is significantly greater than the number of people that plan to leave after the training with a percentage of ~75% to ~25%. Becauase of the uneven class distribution, the model has a potential to be more biased towards the majority class and correctly predicting them, people that aren't looking. This is something to watch out for when evaluating on the test set.
#
# In order to combat this, we will also find the precision, recall and F1-score to better understand how our model is performing.

# %%
precision = precision_score(y_train, y_pred)
print(f"Precision: {precision:.3f}")

# Calculate recall
recall = recall_score(y_train, y_pred)
print(f"Recall: {recall:.3f}")

# Calculate F1 score
f1 = f1_score(y_train, y_pred)
print(f"F1 Score: {f1:.3f}")
# Out:
# Precision: 0.671
# Recall: 0.828
# F1 Score: 0.741

# %%
#Testing the accuracy of the model on the test data
val_probs = rf_model.predict_proba(x_test)
val_probs = val_probs[:, 1]

threshold = 0.6
val_preds = (val_probs >= threshold).astype(y_test.dtype)

val_acc = np.mean(val_preds == y_test)
val_base_rate = np.mean(y_test)
val_rel_acc = np.abs((1 - val_base_rate) - val_acc) * 100

print(f"Model Accuracy: {val_acc:.2f}")
print(f"Model Relative Accuracy: {val_rel_acc:.2f}%")
# Out:
# Model Accuracy: 0.78
# Model Relative Accuracy: 3.26%

# %%
#plotting the confusion matrix on the test set
#val_cm = confusion_matrix(val_preds, y_test, normalize = "true")

val_cm = confusion_matrix(val_preds, y_test, normalize = "true")
print_ConfusionMatrix(val_cm, "Normalized Confusion Matrix for Validation Set", normalized =True)

# %%
val_cm = confusion_matrix(val_preds, y_test)
print_ConfusionMatrix(val_cm, "Raw Values for Validation Confusion Matrix", normalized = False)

# %%
#Looking at the feature importances in our data set
feature_importances = rf_model.feature_importances_

Feature_Importances = pd.DataFrame({
    'Feature': train_dummies.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)
top20 = Feature_Importances.iloc[:20, ]

print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.87      0.90     11503
#          1.0       0.67      0.83      0.74      3823
#
#     accuracy                           0.86     15326
#    macro avg       0.80      0.85      0.82     15326
# weighted avg       0.87      0.86      0.86     15326

# %%
#plotting the top 20 features important in our data set
plt.barh(top20["Feature"], top20["Importance"])
plt.xlabel('Importance')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.figure(dpi = 300)
plt.show()

# %%
#Runnung a neural network on the model
early_stop = EarlyStopping(patience=20, restore_best_weights=True)

hr_nn = tf.keras.Sequential([
    tf.keras.Input(shape=(x_train.shape[1],)),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")])

hr_nn2 = tf.keras.Sequential([
    tf.keras.Input(shape=(x_train.shape[1],)),
    tf.keras.layers.Dense(64, activation="relu"),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")])

# %%
hr_nn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,993 (50.75 KB)
#  Trainable params: 12,993 (50.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compiling the training set
hr_nn.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
hr_nn2.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
#Training the model
history = hr_nn.fit(x=x_train, y=y_train, batch_size=32, callbacks=[early_stop], epochs=50)
history2 = hr_nn2.fit(x=x_train, y=y_train, batch_size=32, callbacks=[early_stop], epochs=50)
# Out:
# Epoch 1/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7549 - loss: 0.5243
# Epoch 2/50
# 100/479 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7612 - loss: 0.4832
# c:\Users\James Cook\anaconda3\envs\behavioral-data-science\Lib\site-packages\keras\src\callbacks\early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7694 - loss: 0.4663
# Epoch 3/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7912 - loss: 0.4412
# Epoch 4/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7878 - loss: 0.4446
# Epoch 5/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7955 - loss: 0.4348
# Epoch 6/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7891 - loss: 0.4371
# Epoch 7/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8054 - loss: 0.4191
# Epoch 8/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8068 - loss: 0.4184
# Epoch 9/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8039 - loss: 0.4122
# Epoch 10/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8124 - loss: 0.4054
# Epoch 11/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8130 - loss: 0.4047
# Epoch 12/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8227 - loss: 0.3956
# Epoch 13/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8225 - loss: 0.3920
# Epoch 14/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8244 - loss: 0.3731
# Epoch 15/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8330 - loss: 0.3756
# Epoch 16/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8259 - loss: 0.3765
# Epoch 17/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8375 - loss: 0.3609
# Epoch 18/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8350 - loss: 0.3602
# Epoch 19/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8430 - loss: 0.3532
# Epoch 20/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8408 - loss: 0.3559
# Epoch 21/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8409 - loss: 0.3463
# Epoch 22/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8485 - loss: 0.3448
# Epoch 23/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8487 - loss: 0.3386
# Epoch 24/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8451 - loss: 0.3348
# Epoch 25/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8535 - loss: 0.3306
# Epoch 26/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8556 - loss: 0.3244
# Epoch 27/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8558 - loss: 0.3213
# Epoch 28/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8540 - loss: 0.3197
# Epoch 29/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8514 - loss: 0.3323
# Epoch 30/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8613 - loss: 0.3103
# Epoch 31/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8608 - loss: 0.3077
# Epoch 32/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8638 - loss: 0.3059
# Epoch 33/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8606 - loss: 0.3055
# Epoch 34/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8634 - loss: 0.2978
# Epoch 35/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8666 - loss: 0.2993
# Epoch 36/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8624 - loss: 0.2954
# Epoch 37/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8648 - loss: 0.2975
# Epoch 38/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8629 - loss: 0.2987
# Epoch 39/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8662 - loss: 0.2934
# Epoch 40/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8713 - loss: 0.2883
# Epoch 41/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8764 - loss: 0.2769
# Epoch 42/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8768 - loss: 0.2781
# Epoch 43/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8703 - loss: 0.2884
# Epoch 44/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8749 - loss: 0.2787
# Epoch 45/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8789 - loss: 0.2735
# Epoch 46/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8768 - loss: 0.2708
# Epoch 47/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8742 - loss: 0.2797
# Epoch 48/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8754 - loss: 0.2749
# Epoch 49/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8796 - loss: 0.2619
# Epoch 50/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8786 - loss: 0.2680
# Epoch 1/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7283 - loss: 0.5350
# Epoch 2/50
#  81/479 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7677 - loss: 0.4743
# c:\Users\James Cook\anaconda3\envs\behavioral-data-science\Lib\site-packages\keras\src\callbacks\early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7747 - loss: 0.4631
# Epoch 3/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7899 - loss: 0.4469
# Epoch 4/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7916 - loss: 0.4442
# Epoch 5/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7874 - loss: 0.4409
# Epoch 6/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7983 - loss: 0.4325
# Epoch 7/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7982 - loss: 0.4294
# Epoch 8/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7986 - loss: 0.4240
# Epoch 9/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8051 - loss: 0.4147
# Epoch 10/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8098 - loss: 0.4110
# Epoch 11/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8095 - loss: 0.4121
# Epoch 12/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8158 - loss: 0.3983
# Epoch 13/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8140 - loss: 0.4013
# Epoch 14/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8198 - loss: 0.3948
# Epoch 15/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8179 - loss: 0.3914
# Epoch 16/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8302 - loss: 0.3774
# Epoch 17/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8261 - loss: 0.3739
# Epoch 18/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8312 - loss: 0.3693
# Epoch 19/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8324 - loss: 0.3621
# Epoch 20/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8320 - loss: 0.3626
# Epoch 21/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8435 - loss: 0.3496
# Epoch 22/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8409 - loss: 0.3486
# Epoch 23/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8377 - loss: 0.3497
# Epoch 24/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8458 - loss: 0.3452
# Epoch 25/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8470 - loss: 0.3409
# Epoch 26/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8479 - loss: 0.3329
# Epoch 27/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8545 - loss: 0.3267
# Epoch 28/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8517 - loss: 0.3240
# Epoch 29/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8570 - loss: 0.3212
# Epoch 30/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8545 - loss: 0.3146
# Epoch 31/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8564 - loss: 0.3182
# Epoch 32/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8633 - loss: 0.3057
# Epoch 33/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8636 - loss: 0.3033
# Epoch 34/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8590 - loss: 0.3055
# Epoch 35/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8656 - loss: 0.3021
# Epoch 36/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8653 - loss: 0.2978
# Epoch 37/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8733 - loss: 0.2877
# Epoch 38/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8717 - loss: 0.2903
# Epoch 39/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8684 - loss: 0.2870
# Epoch 40/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8726 - loss: 0.2797
# Epoch 41/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8727 - loss: 0.2778
# Epoch 42/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8753 - loss: 0.2820
# Epoch 43/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8770 - loss: 0.2753
# Epoch 44/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8816 - loss: 0.2680
# Epoch 45/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8774 - loss: 0.2702
# Epoch 46/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8799 - loss: 0.2676
# Epoch 47/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8821 - loss: 0.2617
# Epoch 48/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8856 - loss: 0.2595
# Epoch 49/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8900 - loss: 0.2503
# Epoch 50/50
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8813 - loss: 0.2611

# %%
#Evaluating the model on the test set
hr_nn.evaluate(x_test, y_test)
hr_nn2.evaluate(x_test,y_test)

nn_val_preds = hr_nn.predict(x_test)
y_pred = (nn_val_preds > 0.7).astype(y_train.dtype)
nn_val_preds2 = hr_nn2.predict(x_test)
y_pred2 = (nn_val_preds2 > 0.7).astype(y_train.dtype)
# Out:
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7501 - loss: 0.8072
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7333 - loss: 0.7474
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.90      0.85      2878
#          1.0       0.50      0.29      0.37       954
#
#     accuracy                           0.75      3832
#    macro avg       0.65      0.60      0.61      3832
# weighted avg       0.72      0.75      0.73      3832

# %%
#Plotting a confusion matrix on the neural net results
nn_val_cm = confusion_matrix(y_test, y_pred, normalize= "true")
print_ConfusionMatrix(nn_val_cm, "Normalized Confusion Matrix for Validation Set", normalized= True)

# %%
nn_val_cm2 = confusion_matrix(y_test, y_pred2, normalize= "true")
print_ConfusionMatrix(nn_val_cm2, "Normalized Confusion Matrix for Validation Set NN2", normalized= True)

# %%
display = RocCurveDisplay.from_predictions(
    y_test,
    nn_val_preds,
    color="#0000AA",
    plot_chance_level=True,
)

_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title="ROC curve for 1st Neural Net"
)

# %%
display = RocCurveDisplay.from_predictions(
    y_test,
    nn_val_preds2,
    color="#0000AA",
    plot_chance_level=True,
)

_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title= "ROC Curve for Second Neural Net"
)

# %%
sns.countplot(x='company_type', stat= "percent" ,data=test_data)
plt.title("Company type")
plt.xticks(rotation=34)
plt.figure(dpi = 300)
plt.show()

# %%
sns.countplot(x='education_level', stat="percent", data=test_data)
plt.title("Education Level")
plt.xticks(rotation=34)
plt.figure(dpi = 300)

# %%
sns.histplot(data=test_data, x='training_hours', stat='density', common_norm=False)
plt.title("Training hours")
# Out:
# Text(0.5, 1.0, 'Training hours')

# %%
sns.countplot(x='last_new_job', data=test_data)
plt.title("Last new job")
plt.xticks(rotation=0)
plt.figure(dpi = 300)

# %%
sns.countplot(x='company_size', data=test_data)
plt.title("Company size")
plt.xticks(rotation=34)
plt.figure(dpi = 300)

# %%
labels = ["Has experience", "No experience"]
dummies_rel_exp = pd.get_dummies(test_data["relevent_experience"])
rel_exp = dummies_rel_exp["Has relevent experience"].sum()
no_rel_exp = dummies_rel_exp["No relevent experience"].sum()
counts = [rel_exp, no_rel_exp]

plt.pie(counts, labels=labels, autopct='%.1f%%', startangle=90)
plt.title("Relevant Experience Breakdown")
plt.legend(labels = ["Has relevant experience", "No relevant experience"])
plt.axis('equal')
plt.figure(dpi = 300)
plt.show()

# %%
test_data["relevent_experience"].keys
# Out:
# <bound method Series.keys of 0       Has relevent experience
# 1       Has relevent experience
# 2        No relevent experience
# 3       Has relevent experience
# 4       Has relevent experience
#                  ...
# 2124     No relevent experience
# 2125    Has relevent experience
# 2126     No relevent experience
# 2127    Has relevent experience
# 2128    Has relevent experience
# Name: relevent_experience, Length: 2129, dtype: object>

# %%
sns.countplot(x='experience', data=test_data)
plt.title("Hours of Experience")
plt.xticks(rotation=65)
plt.figure(dpi = 300)

# %%
test_dummies = pd.get_dummies(test_data, dummy_na= True)


test_dummies.drop(["relevent_experience_nan","enrollee_id"], axis = 1,inplace = True)

# %%
test_dummies
# Out:
#       city_development_index  training_hours  city_city_1  city_city_10  \
# 0                      0.827              21        False         False
# 1                      0.920              98        False         False
# 2                      0.624              15        False         False
# 3                      0.827              39        False         False
# 4                      0.920              72        False         False
# ...                      ...             ...          ...           ...
# 2124                   0.920              15        False         False
# 2125                   0.897              30        False         False
# 2126                   0.887              18        False         False
# 2127                   0.804              84        False         False
# 2128                   0.804              11        False         False
#
#       city_city_100  city_city_101  city_city_102  city_city_103  \
# 0             False          False          False          False
# 1             False          False          False           True
# 2             False          False          False          False
# 3             False          False          False          False
# 4             False          False          False           True
# ...             ...            ...            ...            ...
# 2124          False          False          False           True
# 2125          False          False          False          False
# 2126           True          False          False          False
# 2127          False          False           True          False
# 2128          False          False           True          False
#
#       city_city_104  city_city_105  ...  company_type_Public Sector  \
# 0             False          False  ...                       False
# 1             False          False  ...                       False
# 2             False          False  ...                       False
# 3             False          False  ...                       False
# 4             False          False  ...                       False
# ...             ...            ...  ...                         ...
# 2124          False          False  ...                        True
# 2125          False          False  ...                       False
# 2126          False          False  ...                       False
# 2127          False          False  ...                        True
# 2128          False          False  ...                       False
#
#       company_type_Pvt Ltd  company_type_nan  last_new_job_1  last_new_job_2  \
# 0                    False              True            True           False
# 1                     True             False            True           False
# 2                     True             False           False           False
# 3                     True             False            True           False
# 4                     True             False           False           False
# ...                    ...               ...             ...             ...
# 2124                 False             False           False           False
# 2125                 False              True           False            True
# 2126                  True             False           False           False
# 2127                 False             False            True           False
# 2128                  True             False           False            True
#
#       last_new_job_3  last_new_job_4  last_new_job_>4  last_new_job_never  \
# 0              False           False            False               False
# 1              False           False            False               False
# 2              False           False            False                True
# 3              False           False            False               False
# 4              False           False             True               False
# ...              ...             ...              ...                 ...
# 2124           False            True            False               False
# 2125           False           False            False               False
# 2126           False           False            False                True
# 2127           False           False            False               False
# 2128           False           False            False               False
#
#       last_new_job_nan
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 2124             False
# 2125             False
# 2126             False
# 2127             False
# 2128             False
#
# [2129 rows x 180 columns]

# %%
scaler = MinMaxScaler()
test_normalized = scaler.fit_transform(test_dummies)

# %%
train_dummies
# Out:
#        city_development_index  training_hours  gender_Female  gender_Male  \
# 0                       0.920              36          False         True
# 1                       0.776              47          False         True
# 2                       0.624              83          False        False
# 3                       0.789              52          False        False
# 4                       0.767               8          False         True
# ...                       ...             ...            ...          ...
# 19153                   0.878              42          False         True
# 19154                   0.920              52          False         True
# 19155                   0.920              44          False         True
# 19156                   0.802              97          False         True
# 19157                   0.855             127          False        False
#
#        gender_Other  gender_nan  relevent_experience_Has relevent experience  \
# 0             False       False                                         True
# 1             False       False                                        False
# 2             False        True                                        False
# 3             False        True                                        False
# 4             False       False                                         True
# ...             ...         ...                                          ...
# 19153         False       False                                        False
# 19154         False       False                                         True
# 19155         False       False                                         True
# 19156         False       False                                         True
# 19157         False        True                                        False
#
#        relevent_experience_No relevent experience  \
# 0                                           False
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                           False
# ...                                           ...
# 19153                                        True
# 19154                                       False
# 19155                                       False
# 19156                                       False
# 19157                                        True
#
#        enrolled_university_Full time course  \
# 0                                     False
# 1                                     False
# 2                                      True
# 3                                     False
# 4                                     False
# ...                                     ...
# 19153                                 False
# 19154                                 False
# 19155                                 False
# 19156                                 False
# 19157                                 False
#
#        enrolled_university_Part time course  ...  company_type_Public Sector  \
# 0                                     False  ...                       False
# 1                                     False  ...                       False
# 2                                     False  ...                       False
# 3                                     False  ...                       False
# 4                                     False  ...                       False
# ...                                     ...  ...                         ...
# 19153                                 False  ...                       False
# 19154                                 False  ...                       False
# 19155                                 False  ...                       False
# 19156                                 False  ...                       False
# 19157                                 False  ...                       False
#
#        company_type_Pvt Ltd  company_type_nan  last_new_job_1  last_new_job_2  \
# 0                     False              True            True           False
# 1                      True             False           False           False
# 2                     False              True           False           False
# 3                      True             False           False           False
# 4                     False             False           False           False
# ...                     ...               ...             ...             ...
# 19153                 False              True            True           False
# 19154                 False              True           False           False
# 19155                  True             False           False           False
# 19156                  True             False           False            True
# 19157                 False              True            True           False
#
#        last_new_job_3  last_new_job_4  last_new_job_>4  last_new_job_never  \
# 0               False           False            False               False
# 1               False           False             True               False
# 2               False           False            False                True
# 3               False           False            False                True
# 4               False            True            False               False
# ...               ...             ...              ...                 ...
# 19153           False           False            False               False
# 19154           False            True            False               False
# 19155           False            True            False               False
# 19156           False           False            False               False
# 19157           False           False            False               False
#
#        last_new_job_nan
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 19153             False
# 19154             False
# 19155             False
# 19156             False
# 19157             False
#
# [19158 rows x 71 columns]

# %%
test_dummies
# Out:
#       city_development_index  training_hours  city_city_1  city_city_10  \
# 0                      0.827              21        False         False
# 1                      0.920              98        False         False
# 2                      0.624              15        False         False
# 3                      0.827              39        False         False
# 4                      0.920              72        False         False
# ...                      ...             ...          ...           ...
# 2124                   0.920              15        False         False
# 2125                   0.897              30        False         False
# 2126                   0.887              18        False         False
# 2127                   0.804              84        False         False
# 2128                   0.804              11        False         False
#
#       city_city_100  city_city_101  city_city_102  city_city_103  \
# 0             False          False          False          False
# 1             False          False          False           True
# 2             False          False          False          False
# 3             False          False          False          False
# 4             False          False          False           True
# ...             ...            ...            ...            ...
# 2124          False          False          False           True
# 2125          False          False          False          False
# 2126           True          False          False          False
# 2127          False          False           True          False
# 2128          False          False           True          False
#
#       city_city_104  city_city_105  ...  company_type_Public Sector  \
# 0             False          False  ...                       False
# 1             False          False  ...                       False
# 2             False          False  ...                       False
# 3             False          False  ...                       False
# 4             False          False  ...                       False
# ...             ...            ...  ...                         ...
# 2124          False          False  ...                        True
# 2125          False          False  ...                       False
# 2126          False          False  ...                       False
# 2127          False          False  ...                        True
# 2128          False          False  ...                       False
#
#       company_type_Pvt Ltd  company_type_nan  last_new_job_1  last_new_job_2  \
# 0                    False              True            True           False
# 1                     True             False            True           False
# 2                     True             False           False           False
# 3                     True             False            True           False
# 4                     True             False           False           False
# ...                    ...               ...             ...             ...
# 2124                 False             False           False           False
# 2125                 False              True           False            True
# 2126                  True             False           False           False
# 2127                 False             False            True           False
# 2128                  True             False           False            True
#
#       last_new_job_3  last_new_job_4  last_new_job_>4  last_new_job_never  \
# 0              False           False            False               False
# 1              False           False            False               False
# 2              False           False            False                True
# 3              False           False            False               False
# 4              False           False             True               False
# ...              ...             ...              ...                 ...
# 2124           False            True            False               False
# 2125           False           False            False               False
# 2126           False           False            False                True
# 2127           False           False            False               False
# 2128           False           False            False               False
#
#       last_new_job_nan
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 2124             False
# 2125             False
# 2126             False
# 2127             False
# 2128             False
#
# [2129 rows x 180 columns]

# %%
#rf_test_pred = rf_model.predict(test_normalized)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 rf_test_pred = rf_model.predict(test_normalized)
#
# File c:\Users\James Cook\anaconda3\envs\behavioral-data-science\Lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File c:\Users\James Cook\anaconda3\envs\behavioral-data-science\Lib\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File c:\Users\James Cook\anaconda3\envs\behavioral-data-science\Lib\site-packages\sklearn\ensemble\_forest.py:638, in BaseForest._validate_X_predict(self, X)
#     635 else:
#     636     ensure_all_finite = True
# --> 638 X = validate_data(
#     639     self,
#     640     X,
#     641     dtype=DTYPE,
#     642     accept_sparse="csr",
#     643     reset=False,
#     644     ensure_all_finite=ensure_all_finite,
#     645 )
#     646 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     647     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\James Cook\anaconda3\envs\behavioral-data-science\Lib\site-packages\sklearn\utils\validation.py:2965, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2965     _check_n_features(_estimator, X, reset=reset)
#    2967 return out
#
# File c:\Users\James Cook\anaconda3\envs\behavioral-data-science\Lib\site-packages\sklearn\utils\validation.py:2829, in _check_n_features(estimator, X, reset)
#    2826     return
#    2828 if n_features != estimator.n_features_in_:
# -> 2829     raise ValueError(
#    2830         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2831         f"is expecting {estimator.n_features_in_} features as input."
#    2832     )
#
# ValueError: X has 180 features, but RandomForestClassifier is expecting 71 features as input.

# %%
#hr_nn.predict(test_normalized)
